# %%
import os
while not os.getcwd().endswith("scratch-a"): os.chdir("..")
from eylon.core import *

def dec2bin_got_it(): pass
def dec2bin_coded_it(): pass
def dec2bin_tested_it(): pass
def dec2bin_done(): pass
def bin2dec_got_it(): pass
def bin2dec_coded_it(): pass
def bin2dec_tested_it(): pass
def all_done(): pass

start({
    "dec2bin_got_it()": [],
    "dec2bin_coded_it()": [],
    "dec2bin_tested_it()": [],
    "dec2bin_done()": [],
    "bin2dec_got_it()": [],
    "bin2dec_coded_it()": [],
    "bin2dec_tested_it()": [],
    "all_done()": [],
})
# Out:
# Hi bar-cohen 😁! Let's start the lesson... 🙌

# %%
submit(dec2bin_got_it)

# %%
submit(dec2bin_coded_it)

# %%
submit(dec2bin_tested_it)

# %%
submit(dec2bin_done)

# %%
submit(bin2dec_got_it)

# %%
submit(bin2dec_tested_it)

# %%
submit(bin2dec_coded_it)

# %%
store_all_changes_to_github()
submit(all_done)
# Out:
# [bar-cohen c542876] auto commit...
#  3 files changed, 68 insertions(+), 5 deletions(-)
#  rename Untitled-16.sb3 => 03-binary-numbers/Untitled-16.sb3 (100%)
# To https://github.com/eylon-holon/scratch-a
#    923bc74..c542876  bar-cohen -> bar-cohen
# Congrats bar-cohen! Got it: '03-binary-numbers.all_done'. Gosha is happy :) 👍
