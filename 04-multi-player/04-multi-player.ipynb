# %%
import os
while not os.getcwd().endswith("scratch-a"): os.chdir("..")
from eylon.core import *

def multi_player_here(): pass
def all_done(): pass

start({
    "multi_player_here()": [],
    "all_done()": [],
})
# Out:
# Hi or-itzhak 😁! Let's start the lesson... 🙌

# %%
submit(multi_player_here)

# %%
store_all_changes_to_github()
submit(all_done)
# Out:
# [or-itzhak 93c9815] auto commit...
#  1 file changed, 27 insertions(+), 9 deletions(-)
# To https://github.com/eylon-holon/scratch-a
#    0d721b8..93c9815  or-itzhak -> or-itzhak
# Congrats or-itzhak! Got it: '04-multi-player.all_done'. Gosha is happy :) 👍
