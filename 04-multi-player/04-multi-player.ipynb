# %%
import os
while not os.getcwd().endswith("scratch-a"): os.chdir("..")
from eylon.core import *

def multi_player_here(): pass
def all_done(): pass

start({
    "multi_player_here()": [],
    "all_done()": [],
})
# Out:
# Hi noa-rosenzweig 😁! Let's start the lesson... 🙌

# %%
submit(multi_player_here)
# Out:
# Congrats noa-rosenzweig! Got it: '04-multi-player.multi_player_here'. Gosha is happy :) 👍

# %%
store_all_changes_to_github()
submit(all_done)
# Out:
# [noa-rosenzweig 3f147c9] auto commit...
#  3 files changed, 29 insertions(+), 16 deletions(-)
#  create mode 100644 04-multi-player/Noa.sprite3
# To https://github.com/eylon-holon/scratch-a
#    7cd8bec..3f147c9  noa-rosenzweig -> noa-rosenzweig
# Congrats noa-rosenzweig! Got it: '04-multi-player.all_done'. Gosha is happy :) 👍
