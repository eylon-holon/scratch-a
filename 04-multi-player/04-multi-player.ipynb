# %%
import os
while not os.getcwd().endswith("scratch-a"): os.chdir("..")
from eylon.core import *

def multi_player_here(): pass
def all_done(): pass

start({
    "multi_player_here()": [],
    "all_done()": [],
})
# Out:
# Hi ariel-palomo 😁! Let's start the lesson... 🙌

# %%
submit(multi_player_here)
# Out:
# Congrats ariel-palomo! Got it: '04-multi-player.multi_player_here'. Gosha is happy :) 👍

# %%
store_all_changes_to_github()
submit(all_done)
# Out:
# [ariel-palomo 292e08a] auto commit...
#  3 files changed, 74 insertions(+), 5 deletions(-)
#  create mode 100644 04-multi-player/ariel.sprite3
# To https://github.com/eylon-holon/scratch-a
#    b3f8c27..292e08a  ariel-palomo -> ariel-palomo
# Congrats ariel-palomo! Got it: '04-multi-player.all_done'. Gosha is happy :) 👍
