# %%
import os
while not os.getcwd().endswith("scratch-a"): os.chdir("..")
from eylon.core import *

def multi_player_here(): pass
def all_done(): pass

start({
    "multi_player_here()": [],
    "all_done()": [],
})
# Out:
# Hi yaara-drobles 😁! Let's start the lesson... 🙌

# %%
submit(multi_player_here)
# Out:
# Congrats yaara-drobles! Got it: '04-multi-player.multi_player_here'. Gosha is happy :) 👍

# %%
store_all_changes_to_github()
submit(all_done)
# Out:
# [yaara-drobles 95536c4] auto commit...
#  2 files changed, 73 insertions(+), 7 deletions(-)
# To https://github.com/eylon-holon/scratch-a
#    d1bc056..95536c4  yaara-drobles -> yaara-drobles
# Congrats yaara-drobles! Got it: '04-multi-player.all_done'. Gosha is happy :) 👍
