# %% [markdown]
# תתחילו עבודה בלהריץ את המשבצת הבא

# %%
from eylon.core import *
start({
    "hello()": [
        [[], [], ['Gosha'], ['Hi Gosha']]
    ],
    "min()": [
        [[10, 20], [10], [], []],
        [[20, 10], [10], [], []],
        [[-10, -20], [-20], [], []],
    ],
    "max()": [
        [[10, 20], [20], [], []],
        [[20, 10], [20], [], []],
        [[-10, -20], [-10], [], []],
    ],
})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from eylon.core import *
#       2 start({
#       3     "hello()": [
#       4         [[], [], ['Gosha'], ['Hi Gosha']]
#    (...)
#      15     ],
#      16 })
#
# ModuleNotFoundError: No module named 'eylon'

# %% [markdown]
# עכשיו מימשו את הפונקציה
# אחרי כל שינוי בהגדרה של הפונקציה צריך להריץ את המשבצת
# זה מין כפתור שמור

# %%
def hello():

# %% [markdown]
# תריצו את הפונקציה
# hello()

# %% [markdown]
# סיימו את העבודה בהגשה של הפונקציה

# %%
hello()

# %% [markdown]
# עכשיו הגישו את העבודה לבדיקה

# %%
submit(hello)

# %% [markdown]
# ממשו פונקציה
# min of two variables

# %%
def min(a, b):

# %% [markdown]
# בידקו את הפונקציה

# %%
print(min(10, 20))
print(min(20, 10))
print(min(-10, 20))
print(min(10, -20))

# %% [markdown]
# הגישו את הפונקציה

# %%
submit(min)

# %% [markdown]
# עכשיו תממשו תבדקו והגישו פונקציה
# max of two variables
